# %%
import os

# Directory containing my files
directory = "./train_val_set"

# Iterate over all files in the directory
for filename in os.listdir(directory):
    # Check if the file is a PNG (mask file)
    if filename.endswith(".png") and not filename.endswith("_label.png"):
        # Construct old and new file paths
        old_file = os.path.join(directory, filename)
        new_file = os.path.join(directory, filename.replace(".png", "_label.png"))

        # Rename the file
        os.rename(old_file, new_file)
        print(f"Renamed '{old_file}' to '{new_file}'")

print("Renaming complete.")
# Out:
# Renamed './train_val_set/2021_05_11_10_C_90DJI_0415_height_90m.png' to './train_val_set/2021_05_11_10_C_90DJI_0415_height_90m_label.png'
# Renamed './train_val_set/2021_05_11_10_C_90DJI_0433_height_70m.png' to './train_val_set/2021_05_11_10_C_90DJI_0433_height_70m_label.png'
# Renamed './train_val_set/2021_03_10_10_D_90DJI_0068_height_119m.png' to './train_val_set/2021_03_10_10_D_90DJI_0068_height_119m_label.png'
# Renamed './train_val_set/2021_02_17_10_B_90DJI_0120_height_50m.png' to './train_val_set/2021_02_17_10_B_90DJI_0120_height_50m_label.png'
# Renamed './train_val_set/2021_03_10_10_D_90DJI_0037_height_90m.png' to './train_val_set/2021_03_10_10_D_90DJI_0037_height_90m_label.png'
# Renamed './train_val_set/2021_03_10_10_D_90DJI_0003_height_50m.png' to './train_val_set/2021_03_10_10_D_90DJI_0003_height_50m_label.png'
# Renamed './train_val_set/2021_02_17_10_B_90DJI_0127_height_31m.png' to './train_val_set/2021_02_17_10_B_90DJI_0127_height_31m_label.png'
# ...
